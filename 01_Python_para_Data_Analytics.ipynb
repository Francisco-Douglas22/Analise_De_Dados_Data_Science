# %% [markdown]
# # **Criando e Manipulando DataFrames**

# %%
#import da bibliotecas
import pandas as pd 
import numpy as np
import matplotlib.pylab as plt 
import seaborn as sns 
sns.set()
# %matplotlib inline

# %%
#Criando uma serie de Dados
series = pd.Series([17, 8, 4, np.nan, 12, 18])
series
# Out:
# 0    17.0
# 1     8.0
# 2     4.0
# 3     NaN
# 4    12.0
# 5    18.0
# dtype: float64

# %%
#Tipo de serie
type(series)
# Out:
# pandas.core.series.Series

# %%
#Criando Datas
data = pd.date_range('20220101', periods=365)
data
# Out:
# DatetimeIndex(['2022-01-01', '2022-01-02', '2022-01-03', '2022-01-04',
#                '2022-01-05', '2022-01-06', '2022-01-07', '2022-01-08',
#                '2022-01-09', '2022-01-10',
#                ...
#                '2022-12-22', '2022-12-23', '2022-12-24', '2022-12-25',
#                '2022-12-26', '2022-12-27', '2022-12-28', '2022-12-29',
#                '2022-12-30', '2022-12-31'],
#               dtype='datetime64[ns]', length=365, freq='D')

# %%
#Criando datas2
datas2 = pd.date_range('20220101', periods=365, freq='D')
datas2
# Out:
# DatetimeIndex(['2022-01-01', '2022-01-02', '2022-01-03', '2022-01-04',
#                '2022-01-05', '2022-01-06', '2022-01-07', '2022-01-08',
#                '2022-01-09', '2022-01-10',
#                ...
#                '2022-12-22', '2022-12-23', '2022-12-24', '2022-12-25',
#                '2022-12-26', '2022-12-27', '2022-12-28', '2022-12-29',
#                '2022-12-30', '2022-12-31'],
#               dtype='datetime64[ns]', length=365, freq='D')

# %%
#Tipo
type(datas2)
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %%
#Criando um dataFrame
df = pd.DataFrame(np.random.randn(365, 8), index=datas2, columns=list('ABCDEFGH'))
df
# Out:
#                    A         B         C         D         E         F  \
# 2022-01-01  0.808782 -0.294515  0.954413 -0.837048 -0.666952 -0.401880
# 2022-01-02 -0.844295  0.556501 -1.526858  1.148183  0.542944  1.169495
# 2022-01-03  0.052227  1.441528  1.347042 -0.489331 -1.174664 -0.782877
# 2022-01-04  1.388305 -1.267863 -0.149146 -0.666982  0.428881 -0.042669
# 2022-01-05 -0.006192 -1.861066 -0.101180 -0.689583  0.788798  1.539523
# ...              ...       ...       ...       ...       ...       ...
# 2022-12-27  0.212106 -0.806248 -0.133110 -1.659861  2.172381 -0.043899
# 2022-12-28 -0.516155 -0.057888 -1.251131  0.220068 -1.091861  0.666432
# 2022-12-29 -1.890225 -0.270168 -0.581966 -0.201865  0.388050 -0.173782
# 2022-12-30 -0.618264 -0.759933  2.881808 -0.129023 -1.276197 -2.720214
# 2022-12-31  0.607574  0.189301 -0.640488 -0.283720  1.818439  0.199746
#
#                    G         H
# 2022-01-01 -1.536591  0.916825
# 2022-01-02 -0.349239 -0.871059
# 2022-01-03 -0.766875 -0.326405
# 2022-01-04  0.547514  1.884018
# 2022-01-05  0.254156 -0.813946
# ...              ...       ...
# 2022-12-27 -0.886442  1.657325
# 2022-12-28  0.414309 -2.521176
# 2022-12-29 -0.323150  1.045705
# 2022-12-30  0.242914 -2.077208
# 2022-12-31  1.134658  1.456146
#
# [365 rows x 8 columns]

# %%
#Visualizando as colunas
df.columns
# Out:
# Index(['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H'], dtype='object')

# %%
#Tipo
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
#Gerando valores aleatorios
np.random.randn(12, 6)
# Out:
# array([[-1.65261521,  0.68585088, -0.65273735,  0.44054586,  0.90285193,
#         -0.70942117],
#        [-1.63210013,  1.19457599, -0.34173067, -0.16682612,  0.19640532,
#         -0.08032483],
#        [-0.79840312, -1.16264238,  0.03688398,  1.02263453, -0.35341227,
#          0.46305544],
#        [ 1.377162  , -1.28658973, -1.51185085,  0.12345316,  0.09546656,
#         -0.29926262],
#        [-1.3387816 ,  2.42841165,  1.2477446 ,  0.60008693,  0.49548483,
#         -0.10324517],
#        [-0.52023263, -0.20237625,  1.0667663 ,  0.86934144, -0.63341322,
#         -0.43333734],
#        [-0.85224155,  2.13223199, -0.24475417, -0.57256967, -0.78023118,
#          0.01507235],
#        [ 0.38110247, -0.14147589, -2.93126237,  0.6247235 , -1.37408845,
#         -1.38224618],
#        [ 0.82013562,  0.45839005, -0.30248388, -0.49123094, -0.01655368,
#         -0.34287966],
#        [-1.83340158, -0.20727106, -1.70641233, -1.29882065, -0.7757409 ,
#         -1.99797386],
#        [-0.49404158, -2.32023168, -0.20300679,  1.19100997,  0.94704672,
#          0.11582047],
#        [-1.00155438, -0.16846167,  1.50847532,  1.12038196, -0.32647115,
#          0.54636542]])

# %%
#Outra maneira de criar um DataFrame com valores aleatorios
df2 = pd.DataFrame({
    "A":7,
    "B": pd.Timestamp('20190101'),
    "C": pd.Series(1, index=list(range(4)), dtype='float32'),
    "D": np.array([3] * 4, dtype='int32'),
    "E": pd.Categorical(['test', 'train', 'test', 'train']),
    "F": 'Python'

})

df2
# Out:
#    A          B    C  D      E       F
# 0  7 2019-01-01  1.0  3   test  Python
# 1  7 2019-01-01  1.0  3  train  Python
# 2  7 2019-01-01  1.0  3   test  Python
# 3  7 2019-01-01  1.0  3  train  Python

# %%
# Criando o DataFrame
datas = pd.date_range('20230101', periods=300, freq='D')
df = pd.DataFrame(np.random.randn(300, 10), index=datas, columns= list('ABCDEFGHIJ'))
df.head()
# Out:
#                    A         B         C         D         E         F  \
# 2023-01-01  0.254894 -0.041020  0.886790 -0.546716 -0.769947 -1.291241
# 2023-01-02  0.189280 -0.417503 -0.551309  0.640399 -0.735279  1.743472
# 2023-01-03  0.590984  0.409562 -0.379365 -0.011842  0.698311  1.083766
# 2023-01-04  0.711676 -1.708288 -2.055007 -0.156094  1.154902  1.561967
# 2023-01-05  0.716485 -1.081351 -1.555940  0.813895 -0.183690  0.649471
#
#                    G         H         I         J
# 2023-01-01 -0.523165 -1.252336 -0.360503  1.362173
# 2023-01-02  0.342692  1.742952  1.096072  1.039908
# 2023-01-03 -0.781918  1.179457 -1.011942  0.486396
# 2023-01-04  0.552820 -1.458843 -0.455083  0.276909
# 2023-01-05 -0.377519 -0.538310  0.488315 -0.622884

# %%
#Shape dos dados
df.shape
# Out:
# (300, 10)

# %%
#Adicionando uma nova coluna com valores de 0 a 300
df['K'] = range(300)
df.head()
# Out:
#                    A         B         C         D         E         F  \
# 2023-01-01  0.254894 -0.041020  0.886790 -0.546716 -0.769947 -1.291241
# 2023-01-02  0.189280 -0.417503 -0.551309  0.640399 -0.735279  1.743472
# 2023-01-03  0.590984  0.409562 -0.379365 -0.011842  0.698311  1.083766
# 2023-01-04  0.711676 -1.708288 -2.055007 -0.156094  1.154902  1.561967
# 2023-01-05  0.716485 -1.081351 -1.555940  0.813895 -0.183690  0.649471
#
#                    G         H         I         J  K
# 2023-01-01 -0.523165 -1.252336 -0.360503  1.362173  0
# 2023-01-02  0.342692  1.742952  1.096072  1.039908  1
# 2023-01-03 -0.781918  1.179457 -1.011942  0.486396  2
# 2023-01-04  0.552820 -1.458843 -0.455083  0.276909  3
# 2023-01-05 -0.377519 -0.538310  0.488315 -0.622884  4

# %%
#Criando uma coluna com o Nome Produto
df['Produto'] = (df['A'] + df['B'] * df['D'])
df.head()
# Out:
#                    A         B         C         D         E         F  \
# 2023-01-01  0.254894 -0.041020  0.886790 -0.546716 -0.769947 -1.291241
# 2023-01-02  0.189280 -0.417503 -0.551309  0.640399 -0.735279  1.743472
# 2023-01-03  0.590984  0.409562 -0.379365 -0.011842  0.698311  1.083766
# 2023-01-04  0.711676 -1.708288 -2.055007 -0.156094  1.154902  1.561967
# 2023-01-05  0.716485 -1.081351 -1.555940  0.813895 -0.183690  0.649471
#
#                    G         H         I         J  K   Produto
# 2023-01-01 -0.523165 -1.252336 -0.360503  1.362173  0  0.277320
# 2023-01-02  0.342692  1.742952  1.096072  1.039908  1 -0.078088
# 2023-01-03 -0.781918  1.179457 -1.011942  0.486396  2  0.586134
# 2023-01-04  0.552820 -1.458843 -0.455083  0.276909  3  0.978329
# 2023-01-05 -0.377519 -0.538310  0.488315 -0.622884  4 -0.163622

# %% [markdown]
# ### Visualizando os dados

# %%
#5 Primeiras Linhas
df.head()
# Out:
#                    A         B         C         D         E         F  \
# 2023-01-01  0.254894 -0.041020  0.886790 -0.546716 -0.769947 -1.291241
# 2023-01-02  0.189280 -0.417503 -0.551309  0.640399 -0.735279  1.743472
# 2023-01-03  0.590984  0.409562 -0.379365 -0.011842  0.698311  1.083766
# 2023-01-04  0.711676 -1.708288 -2.055007 -0.156094  1.154902  1.561967
# 2023-01-05  0.716485 -1.081351 -1.555940  0.813895 -0.183690  0.649471
#
#                    G         H         I         J  K   Produto
# 2023-01-01 -0.523165 -1.252336 -0.360503  1.362173  0  0.277320
# 2023-01-02  0.342692  1.742952  1.096072  1.039908  1 -0.078088
# 2023-01-03 -0.781918  1.179457 -1.011942  0.486396  2  0.586134
# 2023-01-04  0.552820 -1.458843 -0.455083  0.276909  3  0.978329
# 2023-01-05 -0.377519 -0.538310  0.488315 -0.622884  4 -0.163622

# %%
#5 ultimas linhas
df.tail()
# Out:
#                    A         B         C         D         E         F  \
# 2023-10-23  0.148369 -0.152395 -0.637949  1.387914  0.272722 -1.373733
# 2023-10-24 -0.253770 -0.369363 -1.735877  0.253053 -0.351743  0.058728
# 2023-10-25 -1.366958 -0.932518 -0.908188  0.547503  1.047943 -1.827190
# 2023-10-26  0.331578  0.178883 -0.694209  1.393090  0.121044 -0.333070
# 2023-10-27 -1.289033 -0.519821  1.179560  0.095250 -1.851102  1.004527
#
#                    G         H         I         J    K   Produto
# 2023-10-23  0.171717  0.028354 -1.942747  0.256869  295 -0.063142
# 2023-10-24  0.284427 -2.230151 -0.480077  0.631307  296 -0.347238
# 2023-10-25  0.344278  1.037381  1.989359 -0.376530  297 -1.877514
# 2023-10-26  0.863099  0.096961 -0.589434  2.280296  298  0.580779
# 2023-10-27  0.099597 -1.495058  0.094597 -0.711284  299 -1.338546

# %%
#Amostra aleatoria dos dados
df.sample(7)
# Out:
#                    A         B         C         D         E         F  \
# 2023-06-04 -1.475783  1.496667 -1.400960  0.045845 -0.089114 -0.049061
# 2023-01-22 -0.810974  1.743000  1.946642  0.708333 -1.231104  0.612086
# 2023-06-28 -0.206336  0.565133  0.411968 -1.140712 -1.478797  0.189769
# 2023-08-16 -0.908091  0.541431 -0.044959 -1.835850  0.011442  0.463176
# 2023-01-17  0.513275  0.561340  0.627512  0.753753  1.591868  0.173155
# 2023-07-05 -0.698021  0.236339  0.314756  1.336310 -0.065541 -1.095139
# 2023-09-29 -0.682918  0.704496 -0.026788 -0.449967 -0.361042 -2.160869
#
#                    G         H         I         J    K   Produto
# 2023-06-04 -0.166074 -0.323760 -1.429879  0.164167  154 -1.407169
# 2023-01-22 -0.635679 -0.301984  1.287152 -0.590194   21  0.423650
# 2023-06-28 -1.478166 -0.252779  0.623714  0.654069  178 -0.850990
# 2023-08-16 -1.008822 -0.795646 -0.716555 -0.847073  227 -1.902077
# 2023-01-17  0.871948 -0.445852  0.885229 -0.967950   16  0.936387
# 2023-07-05 -0.349100 -0.122821  2.379651 -0.243829  185 -0.382199
# 2023-09-29  1.929487  0.118018 -0.284823  1.099170  271 -0.999918

# %%
#Index dos dados
df.index
# Out:
# DatetimeIndex(['2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04',
#                '2023-01-05', '2023-01-06', '2023-01-07', '2023-01-08',
#                '2023-01-09', '2023-01-10',
#                ...
#                '2023-10-18', '2023-10-19', '2023-10-20', '2023-10-21',
#                '2023-10-22', '2023-10-23', '2023-10-24', '2023-10-25',
#                '2023-10-26', '2023-10-27'],
#               dtype='datetime64[ns]', length=300, freq='D')

# %%
#Colunas
df.columns
# Out:
# Index(['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'Produto'], dtype='object')

# %%
#Transformando em uma Matriz do Numpy
df.to_numpy
# Out:
# <bound method DataFrame.to_numpy of                    A         B         C         D         E         F  \
# 2023-01-01  0.254894 -0.041020  0.886790 -0.546716 -0.769947 -1.291241
# 2023-01-02  0.189280 -0.417503 -0.551309  0.640399 -0.735279  1.743472
# 2023-01-03  0.590984  0.409562 -0.379365 -0.011842  0.698311  1.083766
# 2023-01-04  0.711676 -1.708288 -2.055007 -0.156094  1.154902  1.561967
# 2023-01-05  0.716485 -1.081351 -1.555940  0.813895 -0.183690  0.649471
# ...              ...       ...       ...       ...       ...       ...
# 2023-10-23  0.148369 -0.152395 -0.637949  1.387914  0.272722 -1.373733
# 2023-10-24 -0.253770 -0.369363 -1.735877  0.253053 -0.351743  0.058728
# 2023-10-25 -1.366958 -0.932518 -0.908188  0.547503  1.047943 -1.827190
# 2023-10-26  0.331578  0.178883 -0.694209  1.393090  0.121044 -0.333070
# 2023-10-27 -1.289033 -0.519821  1.179560  0.095250 -1.851102  1.004527
#
#                    G         H         I         J    K   Produto
# 2023-01-01 -0.523165 -1.252336 -0.360503  1.362173    0  0.277320
# 2023-01-02  0.342692  1.742952  1.096072  1.039908    1 -0.078088
# 2023-01-03 -0.781918  1.179457 -1.011942  0.486396    2  0.586134
# 2023-01-04  0.552820 -1.458843 -0.455083  0.276909    3  0.978329
# 2023-01-05 -0.377519 -0.538310  0.488315 -0.622884    4 -0.163622
# ...              ...       ...       ...       ...  ...       ...
# 2023-10-23  0.171717  0.028354 -1.942747  0.256869  295 -0.063142
# 2023-10-24  0.284427 -2.230151 -0.480077  0.631307  296 -0.347238
# 2023-10-25  0.344278  1.037381  1.989359 -0.376530  297 -1.877514
# 2023-10-26  0.863099  0.096961 -0.589434  2.280296  298  0.580779
# 2023-10-27  0.099597 -1.495058  0.094597 -0.711284  299 -1.338546
#
# [300 rows x 12 columns]>

# %%
#Obtendo o Transposta dos dados, ou seja troca linha por coluna
df.T.head()
# Out:
#    2023-01-01  2023-01-02  2023-01-03  2023-01-04  2023-01-05  2023-01-06  \
# A    0.254894    0.189280    0.590984    0.711676    0.716485    0.499377
# B   -0.041020   -0.417503    0.409562   -1.708288   -1.081351    0.150891
# C    0.886790   -0.551309   -0.379365   -2.055007   -1.555940    0.793856
# D   -0.546716    0.640399   -0.011842   -0.156094    0.813895   -0.019037
# E   -0.769947   -0.735279    0.698311    1.154902   -0.183690   -0.754499
#
#    2023-01-07  2023-01-08  2023-01-09  2023-01-10  ...  2023-10-18  \
# A   -1.174147    0.266340   -1.359308    0.357339  ...    0.884585
# B    2.148695    1.142461    1.084333   -1.323264  ...   -0.980206
# C   -0.326701    1.815069    0.375218    1.510610  ...   -1.236208
# D    0.238212   -1.370690    0.553933   -0.306128  ...    0.323676
# E   -1.146042    0.260130    2.912718    0.391817  ...   -0.961520
#
#    2023-10-19  2023-10-20  2023-10-21  2023-10-22  2023-10-23  2023-10-24  \
# A    0.200296   -0.578315    0.588942    1.947277    0.148369   -0.253770
# B   -0.756611    0.085780    1.055592    2.061705   -0.152395   -0.369363
# C    2.785684   -0.130300    2.110242    0.079374   -0.637949   -1.735877
# D    0.872209    1.533246    0.505988    1.078488    1.387914    0.253053
# E    2.010194    1.920261    2.224336    1.176244    0.272722   -0.351743
#
#    2023-10-25  2023-10-26  2023-10-27
# A   -1.366958    0.331578   -1.289033
# B   -0.932518    0.178883   -0.519821
# C   -0.908188   -0.694209    1.179560
# D    0.547503    1.393090    0.095250
# E    1.047943    0.121044   -1.851102
#
# [5 rows x 300 columns]

# %% [markdown]
# ### Combinando DataFrames

# %% [markdown]
# #### Criaremos 3 dataframes

# %%
#Criando o DataFrame 1
datas - pd.date_range('20230101', periods=300, freq='D')
df1 = pd.DataFrame(np.random.randn(300, 10), index=datas, columns=list('ABCDEFGHIJ'))
df1.head()
# Out:
#                    A         B         C         D         E         F  \
# 2023-01-01  0.217412  0.335733 -0.223414 -1.767206  0.884837  0.308729
# 2023-01-02 -0.011056 -0.018604  0.433131 -0.142899  0.798397 -0.123364
# 2023-01-03  0.330842  0.329340 -1.335909 -1.960199  0.176172 -0.055386
# 2023-01-04  1.882455 -0.141128 -1.422093  1.933944 -0.543661 -1.697060
# 2023-01-05 -0.226731 -0.385146  1.164052  0.747729  0.650370  0.640390
#
#                    G         H         I         J
# 2023-01-01  1.069939 -0.555140  0.761168  0.468126
# 2023-01-02 -0.315072  0.576865 -0.685130  1.434015
# 2023-01-03 -0.842795 -2.546262 -1.324634 -1.098830
# 2023-01-04  0.428754  1.135622  1.893285 -1.075525
# 2023-01-05  0.413166  0.713396  0.433723  1.327996

# %%
#Criando o DataFrame 2
datas = pd.date_range('20240101', periods=300, freq='D')
df2 = pd.DataFrame(np.random.randn(300, 10), index=datas, columns=list('ABCDEFGHIJ'))
df2.head()
# Out:
#                    A         B         C         D         E         F  \
# 2024-01-01 -0.367042 -0.259050 -0.004659  0.683774 -1.600034 -0.489441
# 2024-01-02  0.205043 -0.249425 -0.201609  0.181618  0.087237  1.416293
# 2024-01-03 -0.132101  0.605127  1.460823  1.225274 -0.884855  2.517340
# 2024-01-04 -0.130017  0.033650 -0.563581 -2.880093 -1.063747 -0.899675
# 2024-01-05  0.487924  0.312862 -0.126233 -1.457734  1.424851  0.343504
#
#                    G         H         I         J
# 2024-01-01 -0.521313 -0.282572 -1.771377  0.648103
# 2024-01-02 -1.276488  1.540325  1.625634  0.616591
# 2024-01-03  0.099988  0.066626  0.614243  1.438753
# 2024-01-04  0.409473 -0.164808 -0.076149  0.033034
# 2024-01-05 -0.215078 -1.543391 -0.803823  0.193455

# %%
#Criando o DataFrame3
datas = pd.date_range('20250101', periods=300, freq='D')
df3 = pd.DataFrame(np.random.randn(300, 10), index=datas, columns=list('ABCDEFGHIJ'))
df3.head()
# Out:
#                    A         B         C         D         E         F  \
# 2025-01-01 -1.274386 -1.757925 -1.988050 -0.389591 -0.154995 -0.428043
# 2025-01-02 -0.108603  0.147388  0.680502 -2.195020  0.803133 -0.402568
# 2025-01-03  0.814239 -0.801221  0.520507 -2.332141 -1.780290  1.403269
# 2025-01-04  1.515206 -0.524674 -0.428363 -1.157197  0.093620  0.077025
# 2025-01-05  1.339284 -0.233283  0.456886  1.366986 -1.022248  0.106601
#
#                    G         H         I         J
# 2025-01-01  0.728079  0.580302  0.801612  1.128833
# 2025-01-02  0.089242 -1.923083  1.101115  1.603660
# 2025-01-03  1.204638 -1.827378  1.274303  0.261076
# 2025-01-04  1.237706 -0.334128  0.325890 -1.191817
# 2025-01-05 -1.464427 -0.297659  0.188927 -0.834686

# %%
#Junção dos Dataframes Concatenação
#A Forma mais correta de se fazer e
frames = pd.concat([df1, df2, df3])
print(frames.head())
print(frames.tail())
# Out:
#                    A         B         C         D         E         F  \
# 2023-01-01  0.217412  0.335733 -0.223414 -1.767206  0.884837  0.308729
# 2023-01-02 -0.011056 -0.018604  0.433131 -0.142899  0.798397 -0.123364
# 2023-01-03  0.330842  0.329340 -1.335909 -1.960199  0.176172 -0.055386
# 2023-01-04  1.882455 -0.141128 -1.422093  1.933944 -0.543661 -1.697060
# 2023-01-05 -0.226731 -0.385146  1.164052  0.747729  0.650370  0.640390
#
#                    G         H         I         J
# 2023-01-01  1.069939 -0.555140  0.761168  0.468126
# 2023-01-02 -0.315072  0.576865 -0.685130  1.434015
# 2023-01-03 -0.842795 -2.546262 -1.324634 -1.098830
# 2023-01-04  0.428754  1.135622  1.893285 -1.075525
# 2023-01-05  0.413166  0.713396  0.433723  1.327996
#                    A         B         C         D         E         F  \
# 2025-10-23  0.457830 -0.774611  0.469187  0.749474  0.455880  0.073441
# 2025-10-24  0.088270 -0.733561 -1.334909 -1.030037 -0.584484  0.809775
# 2025-10-25  0.044400 -1.847410 -1.432317  0.649241  0.084831  0.005249
# 2025-10-26  1.291296  1.313544 -0.053751 -0.657928 -0.028264 -0.903923
# 2025-10-27 -0.495837 -0.931497  0.462476 -1.091955 -0.834324 -0.562370
#
#                    G         H         I         J
# 2025-10-23  1.534731  0.509830 -0.590914 -0.786198
# 2025-10-24  0.034619 -1.104588 -1.429235  0.705494
# 2025-10-25 -0.702401  2.093501  0.309312 -0.184558
# 2025-10-26  0.368012  1.927581 -0.903769 -0.848449
# 2025-10-27 -0.100582 -0.896392  0.462590 -0.063542

# %%
#Shape dos Dados
frames.shape
# Out:
# (900, 10)

# %%
#Concatenando os DataFrames e Identificando cada pela chave keys
dfs = pd.concat([df1, df2, df3], keys=['Dados1', 'Dados2', 'Dados3'])
dfs.head()
# Out:
#                           A         B         C         D         E         F  \
# Dados1 2023-01-01  0.217412  0.335733 -0.223414 -1.767206  0.884837  0.308729
#        2023-01-02 -0.011056 -0.018604  0.433131 -0.142899  0.798397 -0.123364
#        2023-01-03  0.330842  0.329340 -1.335909 -1.960199  0.176172 -0.055386
#        2023-01-04  1.882455 -0.141128 -1.422093  1.933944 -0.543661 -1.697060
#        2023-01-05 -0.226731 -0.385146  1.164052  0.747729  0.650370  0.640390
#
#                           G         H         I         J
# Dados1 2023-01-01  1.069939 -0.555140  0.761168  0.468126
#        2023-01-02 -0.315072  0.576865 -0.685130  1.434015
#        2023-01-03 -0.842795 -2.546262 -1.324634 -1.098830
#        2023-01-04  0.428754  1.135622  1.893285 -1.075525
#        2023-01-05  0.413166  0.713396  0.433723  1.327996

# %%
#Usando o Loc para visualiza os valores df2
dfs.loc['Dados2'].head()
# Out:
#                    A         B         C         D         E         F  \
# 2024-01-01 -0.367042 -0.259050 -0.004659  0.683774 -1.600034 -0.489441
# 2024-01-02  0.205043 -0.249425 -0.201609  0.181618  0.087237  1.416293
# 2024-01-03 -0.132101  0.605127  1.460823  1.225274 -0.884855  2.517340
# 2024-01-04 -0.130017  0.033650 -0.563581 -2.880093 -1.063747 -0.899675
# 2024-01-05  0.487924  0.312862 -0.126233 -1.457734  1.424851  0.343504
#
#                    G         H         I         J
# 2024-01-01 -0.521313 -0.282572 -1.771377  0.648103
# 2024-01-02 -1.276488  1.540325  1.625634  0.616591
# 2024-01-03  0.099988  0.066626  0.614243  1.438753
# 2024-01-04  0.409473 -0.164808 -0.076149  0.033034
# 2024-01-05 -0.215078 -1.543391 -0.803823  0.193455

# %% [markdown]
# ### Merge e GroupBy

# %% [markdown]
# Para representação do Merge, usaremos Dados Ficticios de 2 Lojas

# %%
#Cadastro da Loja A
# Cadastro da Loja A

cadastro_a = {'Id': ['AA2930', 'BB4563', 'CC2139', 'DE2521', 'GT3462', 'HH1158'],
            "Nome": ['Victor', 'Amanda', 'Bruna', 'Carlos', 'Ricardo', 'Maria'],
            "Idade": [20, 35, 40, 54, 30, 27],
            "CEP": ['00092-029', '11111-111', '00000-999', '22222-888', '88888-111', '77777-666']}

cadastro_a = pd.DataFrame(cadastro_a, columns=['Id', 'Nome', 'Idade', 'CEP'])
cadastro_a
# Out:
#        Id     Nome  Idade        CEP
# 0  AA2930   Victor     20  00092-029
# 1  BB4563   Amanda     35  11111-111
# 2  CC2139    Bruna     40  00000-999
# 3  DE2521   Carlos     54  22222-888
# 4  GT3462  Ricardo     30  88888-111
# 5  HH1158    Maria     27  77777-666

# %%
# Cadastro da Loja B

cadastro_b = {'Id': ['CC9999', 'EF4488', 'DD9999', 'GT3462', 'HH1158'],
            "Nome": ['Marcos', 'Patricia', 'Ericka', 'Ricardo', 'Maria'],
            "Idade": [19, 30, 22, 30, 27],
            "CEP": ['00092-029', '11111-111', '11111-888', '88888-111', '77777-666']}

cadastro_b = pd.DataFrame(cadastro_b, columns=['Id', 'Nome', 'Idade', 'CEP'])
cadastro_b
# Out:
#        Id      Nome  Idade        CEP
# 0  CC9999    Marcos     19  00092-029
# 1  EF4488  Patricia     30  11111-111
# 2  DD9999    Ericka     22  11111-888
# 3  GT3462   Ricardo     30  88888-111
# 4  HH1158     Maria     27  77777-666

# %%
# Registros de Compras de Todas Unidades

compras = {'Id': ['AA2930', 'EF4488', 'CC2139', 'EF4488', 'CC9999', 'AA2930', 'HH1158', 'HH1158'],
        "Data": ['2019-01-01', '2019-01-30', '2019-02-01', '2019-02-20',
        '2019-03-15', '2019-04-25', '2019-04-30', '2019-05-22'],
        'Valor': [200, 100, 45, 150, 300, 35, 50, 450]}

compras = pd.DataFrame(compras, columns=['Id', 'Data', 'Valor'])
compras
# Out:
#        Id        Data  Valor
# 0  AA2930  2019-01-01    200
# 1  EF4488  2019-01-30    100
# 2  CC2139  2019-02-01     45
# 3  EF4488  2019-02-20    150
# 4  CC9999  2019-03-15    300
# 5  AA2930  2019-04-25     35
# 6  HH1158  2019-04-30     50
# 7  HH1158  2019-05-22    450

# %%
#Intersecao da LojaA com a LojaB
from IPython.display import Image
Image('merge.png')

# %% [markdown]
# ### **Inner Join**

# %%
#Interseção de ID, Idade e CEP
pd.merge(cadastro_a, cadastro_b, on=['Id'], how='inner')
# Out:
#        Id   Nome_x  Idade_x      CEP_x   Nome_y  Idade_y      CEP_y
# 0  GT3462  Ricardo       30  88888-111  Ricardo       30  88888-111
# 1  HH1158    Maria       27  77777-666    Maria       27  77777-666

# %%
#Outra Forma
pd.merge(cadastro_a, cadastro_b[['Id', 'Idade', 'CEP']], on=['Id'], how='inner')
# Out:
#        Id     Nome  Idade_x      CEP_x  Idade_y      CEP_y
# 0  GT3462  Ricardo       30  88888-111       30  88888-111
# 1  HH1158    Maria       27  77777-666       27  77777-666

# %%
#Mudança de Sufixo
pd.merge(cadastro_a, cadastro_b[['Id', 'Idade', 'CEP']], on=['Id'], how='inner', suffixes=('_A', '_B'))
# Out:
#        Id     Nome  Idade_A      CEP_A  Idade_B      CEP_B
# 0  GT3462  Ricardo       30  88888-111       30  88888-111
# 1  HH1158    Maria       27  77777-666       27  77777-666

# %% [markdown]
# ### **Full Join**

# %%
#Lojas
lojas = pd.concat([cadastro_a, cadastro_b], ignore_index=True)
lojas
# Out:
#         Id      Nome  Idade        CEP
# 0   AA2930    Victor     20  00092-029
# 1   BB4563    Amanda     35  11111-111
# 2   CC2139     Bruna     40  00000-999
# 3   DE2521    Carlos     54  22222-888
# 4   GT3462   Ricardo     30  88888-111
# 5   HH1158     Maria     27  77777-666
# 6   CC9999    Marcos     19  00092-029
# 7   EF4488  Patricia     30  11111-111
# 8   DD9999    Ericka     22  11111-888
# 9   GT3462   Ricardo     30  88888-111
# 10  HH1158     Maria     27  77777-666

# %%
#Removendo os dados Duplicados de Loja
clientes_unicos = lojas.drop_duplicates(subset='Id')
clientes_unicos
# Out:
#        Id      Nome  Idade        CEP
# 0  AA2930    Victor     20  00092-029
# 1  BB4563    Amanda     35  11111-111
# 2  CC2139     Bruna     40  00000-999
# 3  DE2521    Carlos     54  22222-888
# 4  GT3462   Ricardo     30  88888-111
# 5  HH1158     Maria     27  77777-666
# 6  CC9999    Marcos     19  00092-029
# 7  EF4488  Patricia     30  11111-111
# 8  DD9999    Ericka     22  11111-888

# %% [markdown]
# ### **Left Join**

# %%
#Left join uni a esquerda
esquerda = pd.merge(cadastro_a, compras, how='left', on='Id')
esquerda
# Out:
#        Id     Nome  Idade        CEP        Data  Valor
# 0  AA2930   Victor     20  00092-029  2019-01-01  200.0
# 1  AA2930   Victor     20  00092-029  2019-04-25   35.0
# 2  BB4563   Amanda     35  11111-111         NaN    NaN
# 3  CC2139    Bruna     40  00000-999  2019-02-01   45.0
# 4  DE2521   Carlos     54  22222-888         NaN    NaN
# 5  GT3462  Ricardo     30  88888-111         NaN    NaN
# 6  HH1158    Maria     27  77777-666  2019-04-30   50.0
# 7  HH1158    Maria     27  77777-666  2019-05-22  450.0

# %% [markdown]
# ### **Utilizando o GroupBy**

# %%
esquerda.groupby(['Id', 'Nome'])['Valor'].sum()
# Out:
# Id      Nome
# AA2930  Victor     235.0
# BB4563  Amanda       0.0
# CC2139  Bruna       45.0
# DE2521  Carlos       0.0
# GT3462  Ricardo      0.0
# HH1158  Maria      500.0
# Name: Valor, dtype: float64

# %% [markdown]
# #### **Outer Join**

# %%
pd.merge(cadastro_a, cadastro_b, how='outer', on=['Id'], indicator=True)
# Out:
#        Id   Nome_x  Idade_x      CEP_x    Nome_y  Idade_y      CEP_y  \
# 0  AA2930   Victor     20.0  00092-029       NaN      NaN        NaN
# 1  BB4563   Amanda     35.0  11111-111       NaN      NaN        NaN
# 2  CC2139    Bruna     40.0  00000-999       NaN      NaN        NaN
# 3  DE2521   Carlos     54.0  22222-888       NaN      NaN        NaN
# 4  GT3462  Ricardo     30.0  88888-111   Ricardo     30.0  88888-111
# 5  HH1158    Maria     27.0  77777-666     Maria     27.0  77777-666
# 6  CC9999      NaN      NaN        NaN    Marcos     19.0  00092-029
# 7  EF4488      NaN      NaN        NaN  Patricia     30.0  11111-111
# 8  DD9999      NaN      NaN        NaN    Ericka     22.0  11111-888
#
#        _merge
# 0   left_only
# 1   left_only
# 2   left_only
# 3   left_only
# 4        both
# 5        both
# 6  right_only
# 7  right_only
# 8  right_only

# %% [markdown]
# # Usando o GroupBy
# # GroupBy - Agrupa por

# %%
#Criando um Novo DataFrame

df = pd.DataFrame({'A': ['verdadeiro', 'falso', 'verdadeiro', 'falso',
                        'verdadeiro', 'falso', 'verdadeiro', 'falso'],
                  'B': ['um', 'um', 'dois', 'tres', 'dois', 'dois', 'um', 'tres'],
                  'C': np.random.randn(8),
                  'D': np.random.randn(8)})
df
# Out:
#             A     B         C         D
# 0  verdadeiro    um -0.299054  0.290533
# 1       falso    um  0.004361  0.031946
# 2  verdadeiro  dois -1.433359 -0.230658
# 3       falso  tres  2.540369 -1.010825
# 4  verdadeiro  dois -0.417187 -0.280979
# 5       falso  dois  1.464572 -1.947604
# 6  verdadeiro    um -0.571213 -0.237344
# 7       falso  tres -0.729841  1.169221

# %%
# Agrupando pela soma da coluna A
df.groupby(['A']).sum()
# Out:
#                          B         C         D
# A
# falso       umtresdoistres  3.279460 -1.757263
# verdadeiro    umdoisdoisum -2.720813 -0.458447

# %%
#Agrupando pela soma da coluna B
df.groupby(['B']).sum()
# Out:
#                               A         C         D
# B
# dois  verdadeiroverdadeirofalso -0.385974 -2.459241
# tres                 falsofalso  1.810528  0.158396
# um    verdadeirofalsoverdadeiro -0.865906  0.085135

# %%
#Agrupando pela soma das coluna A e B
df.groupby(['A', 'B']).sum()
# Out:
#                         C         D
# A          B
# falso      dois  1.464572 -1.947604
#            tres  1.810528  0.158396
#            um    0.004361  0.031946
# verdadeiro dois -1.850546 -0.511637
#            um   -0.870267  0.053190

# %% [markdown]
# ### **Reshape de Dados - Reformula/Reorganiza os Dados**
